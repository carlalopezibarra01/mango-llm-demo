# %%
model_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0"
local_dir="models/TinyLlama-1.1B-Chat-v1.0"

# %%
from huggingface_hub import snapshot_download
snapshot_download(
    repo_id=model_id,
    local_dir=local_dir,
    local_dir_use_symlinks=False,
)
# Out:
# c:\Users\34699\Documents\mango-llm-demo\.venv\Lib\site-packages\huggingface_hub\file_download.py:979: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 10 files: 100%|██████████| 10/10 [00:00<00:00, 147.30it/s]
# 'C:\\Users\\34699\\Documents\\mango-llm-demo\\.venv\\models\\TinyLlama-1.1B-Chat-v1.0'

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# %%
tokenizer=AutoTokenizer.from_pretrained(local_dir,local_files_only=True)
device="cpu"

# %%
model=AutoModelForCausalLM.from_pretrained(local_dir, torch_dtype=torch.float32,local_files_only=True).to(device)

# %%
messages= [
    {"role":"system","content": "You are a helpful assistant"},
    {"role":"user","content":"What is GDP in economics?"}
]

# %%
inputs=tokenizer.apply_chat_template(
    messages,
    add_generation_promt=True,
    tokenize=True,
    return_dict=True,
    return_tensors="pt",
).to(device)

# %%
outputs=model.generate(**inputs,max_new_tokens=80)

# %%
print(tokenizer.decode(outputs[0][inputs["input_ids"].shape[-1]:]))
# Out:
# <|assistant|>
# Gross Domestic Product (GDP) is a measure of the total value of all final goods and services produced within a country in a given time period. It is calculated by adding up the values of all the individual economic activities that contribute to the production of goods and services. GDP is a key indicator of a country's economic health and growth, as
